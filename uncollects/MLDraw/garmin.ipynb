# %%
from garmin_fit_sdk import Decoder, Stream

# %%
FitFile = "/home/anyinlover/HealthData/FitFiles/Activities/13302319459_ACTIVITY.fit"

# %%
stream = Stream.from_file(FitFile)
decoder = Decoder(stream)
messages, errors = decoder.read()

# %%
messages
# Out:
# {'file_id_mesgs': [{'serial_number': 3431066335,
#    'time_created': datetime.datetime(2023, 12, 31, 13, 3, 42, tzinfo=datetime.timezone.utc),
#    'manufacturer': 'garmin',
#    'product': 3992,
#    'type': 'activity',
#    'garmin_product': 'fr255'}],
#  'file_creator_mesgs': [{'software_version': 1619}],
#  '288': [{253: 1072962222, 2: 17, 0: 6, 1: 70}],
#  '327': [{253: 1072962222, 3: 12, 4: 4004, 5: 4, 0: 10, 1: 1, 2: 2, 6: 0},
#   {253: 1072962222, 3: 12, 4: 4004, 5: 4, 0: 10, 1: 1, 2: 2, 6: 0},
#   {253: 1072962227, 3: 12, 4: 12196, 5: 4, 0: 10, 1: 1, 2: 2, 6: 0}],
#  '326': [{253: 1072962222, 0: 49, 1: 15827},
#   {253: 1072962222, 0: 49, 1: 467},
#   {253: 1072962223, 0: 49, 1: 467},
#   {253: 1072962227, 0: 49, 1: 15827},
#   {253: 1072962227, 0: 49, 1: 467},
#   {253: 1072962228, 0: 49, 1: 15827},
#   {253: 1072962228, 0: 49, 1: 467},
#   {253: 1072962229, 0: 49, 1: 467},
#   {253: 1072962444, 0: 11},
#   {253: 1072962444, 0: 3},
#   {253: 1072962444, 0: 25, 1: 3},
# ...
